# %% [markdown]
# # **Import Libraries**

# %%
import pandas as pd
import numpy as np
import re
import time
import random

from bertopic import BERTopic
from sentence_transformers import SentenceTransformer
from umap.umap_ import UMAP
import hdbscan
import torch

import nlp_id
from nlp_id.tokenizer import Tokenizer
from nlp_id.stopword import StopWord

from openpyxl import Workbook
from openpyxl.styles import Font, Alignment, PatternFill
from openpyxl.utils.dataframe import dataframe_to_rows

import warnings
warnings.filterwarnings('ignore')
pd.set_option("display.max_colwidth", None)
pd.set_option("display.max_columns", None)

# %%
import os
os.chdir("..")
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %%
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)

# %% [markdown]
# # **Prepare Dataset**

# %%
df_modeling = pd.read_csv('src/data/df_modeling_BERT.csv')
df_modeling.head()
# Out:
#                                                                                                                                                                                                               cleaned_text  \
# 0  saya suka materi yang sudah disiapkan oleh pihak kampus karena memudahkan mahasiswa saya juga menyukai program enrichment yang disediakan kampus saya sehingga mahasiswa dapat belajar di ruang lingkup yang lebih luas
# 1                                                                                              bisa bertemu dengan teman teman baru dan mendapatkan koneksi serta mendapatkan pelajaran yang berguna bagi saya kedepan nya
# 2                                                                                         saya suka dengan makanan yang ada di dalam kampus saya terutama bakmi efata selain itu disekitar kampus juga banyak makanan enak
# 3                                                                                                               fasilitas kampus alam sutera sangat bagus pelajaran lab diajarkan oleh asisten yang sangat mengerti materi
# 4                                                                                                saya suka dengan pertemanan nya solid mau saling bantu satu sama lain bagi bagi kisi kisi pas ujian terus saling ngajarin
#
#   sentiment
# 0  positive
# 1  positive
# 2  positive
# 3  positive
# 4  positive

# %%
from utils.topic_prediction import prepare_dataset
texts_pos, texts_neg = prepare_dataset(df_modeling)

# %% [markdown]
# # **Multiple Tuning**

# %%
# embedding_models = [
#     "LazarusNLP/all-indo-e5-small-v4",
#     "paraphrase-multilingual-MiniLM-L12-v2",
#     "sentence-transformers/multi-qa-MiniLM-L6-cos-v1"
# ]

# umap_params = [
#     {"n_neighbors": 7, "min_dist": 0.0, "metric": "cosine"},
#     {"n_neighbors": 5, "min_dist": 0.1, "metric": "euclidean"},
#     {"n_neighbors": 5, "min_dist": 0.0, "metric": "cosine"},
#     {"n_neighbors": 7, "min_dist": 0.1, "metric": "euclidean"},
#     {"n_neighbors": 10, "min_dist": 0.1, "metric": "cosine"},
#     {"n_neighbors": 15, "min_dist": 0.3, "metric": "euclidean"}
# ]

# hdbscan_params = [
#     {"min_cluster_size": 10, "min_samples": 3, "cluster_selection_epsilon": 0.0},
#     {"min_cluster_size": 5, "min_samples": 3, "cluster_selection_epsilon": 0.5},
#     {"min_cluster_size": 5, "min_samples": 3, "cluster_selection_epsilon": 0.3},
#     {"min_cluster_size": 10, "min_samples": 3, "cluster_selection_epsilon": 0.3},
#     {"min_cluster_size": 15, "min_samples": 5, "cluster_selection_epsilon": 0.0},
#     {"min_cluster_size": 10, "min_samples": 5, "cluster_selection_epsilon": 0.5},
# ]

# bertopic_params = [
#     {"top_n_words": 5, "nr_topics": 3},
#     {"top_n_words": 5, "nr_topics": 4},
#     {"top_n_words": 5, "nr_topics": 5},
#     {"top_n_words": 5, "nr_topics": 6},
#     {"top_n_words": 10, "nr_topics": 3},
#     {"top_n_words": 10, "nr_topics": 4},
#     {"top_n_words": 10, "nr_topics": 5},
#     {"top_n_words": 10, "nr_topics": 6},
# ]

# %%
embedding_models = [
    "LazarusNLP/all-indo-e5-small-v4"  # best Indo-focused choice
]

umap_params = [
    {"n_neighbors": 5, "min_dist": 0.0, "metric": "cosine"},
]

hdbscan_params = [
    {"min_cluster_size": 5, "min_samples": 3, "cluster_selection_epsilon": 0.0},
]

bertopic_params = [
    {"top_n_words": 5, "nr_topics": 4},
]

# %%
from utils.topic_evaluation import calculate_coherence_score, calculate_irbo, evaluate_topics

def run_topic_modeling(label, top_k=3):
    all_start_time = time.time()

    texts = texts_pos if label == "positive" else texts_neg
    results = []

    for emb in embedding_models:
        embedding_model = SentenceTransformer(emb)

        for u in umap_params:
            umap_model = None if u is None else UMAP(**{**u, "random_state": 42})

            for h in hdbscan_params:
                hdbscan_model = None if h is None else hdbscan.HDBSCAN(**h)

                for b in bertopic_params:
                    model_start_time = time.time()

                    topic_model = BERTopic(
                        embedding_model=embedding_model,
                        umap_model=umap_model,
                        hdbscan_model=hdbscan_model,
                        top_n_words=b["top_n_words"],
                        nr_topics=b["nr_topics"],
                        verbose=False
                    )

                    topic_model.fit(texts)
                    coherence_scores, irbo_score = evaluate_topics(texts, topic_model)

                    topics_dict = topic_model.get_topics()
                    topics_filtered = {k: v for k, v in topics_dict.items() if k != -1 and v is not None}

                    model_time = round(time.time() - model_start_time, 2)
                    
                    results.append({
                        "Label": label,
                        "Embedding Model": emb,
                        "UMAP": u,
                        "HDBSCAN": h,
                        "BERTopic Params": b,
                        "Num Topics": len(topics_filtered),
                        "Topics List": [[word for word, _ in words] for words in topics_filtered.values()],
                        **coherence_scores,
                        "IRBO": irbo_score,
                        "Model Time (s)": model_time
                    })

                    print(f"[✓] Finished model - Embedding: {emb}, UMAP: {u}, HDBSCAN: {h}, BERTopic Params: {b} | Time: {model_time}s")

    total_time = round(time.time() - all_start_time, 2)
    print(f"\nAll models completed in {total_time} seconds.")
    results_topk = pd.DataFrame(results).sort_values(by='c_v', ascending=False).head(top_k)

    for i in range(len(results_topk)):
        emb = results_topk['Embedding Model'].iloc[i]
        u = results_topk['UMAP'].iloc[i]
        h = results_topk['HDBSCAN'].iloc[i]
        b = results_topk['BERTopic Params'].iloc[i]

        embedding_model = SentenceTransformer(emb)
        umap_model = None if u is None else UMAP(**{**u, "random_state": 42})
        hdbscan_model = None if h is None else hdbscan.HDBSCAN(**h)

        bertopic_model = BERTopic(
            embedding_model=embedding_model,
            umap_model=umap_model,
            hdbscan_model=hdbscan_model,
            top_n_words=b["top_n_words"],
            nr_topics=b["nr_topics"],
            verbose=False
        )

        bertopic_model.fit(texts)

        model_save_path = f'src/models/bertopic_top{top_k}/{label}/best_{label}_model_top{i+1}'
        embedding_save_path = f'src/models/bertopic_top{top_k}/{label}/embeddings_top{i+1}'

        embedding_model.save(embedding_save_path)
        bertopic_model.save(
            model_save_path,
            serialization="safetensors",
        )
        print(f"Model saved to {model_save_path}, embedding saved to {embedding_save_path}")

    return results

# %% [markdown]
# ### **Positive**

# %%
positive_results = run_topic_modeling("positive")
# Out:
# Coherence (c_v): 0.577
# Coherence (u_mass): -2.922
# Coherence (c_uci): 0.053
# Coherence (c_npmi): 0.129
# IRBO Topic Diversity: 0.843
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 3} | Time: 31.73s
# Coherence (c_v): 0.564
# Coherence (u_mass): -2.453
# Coherence (c_uci): 0.087
# Coherence (c_npmi): 0.1
# IRBO Topic Diversity: 0.874
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 4} | Time: 11.88s
# Coherence (c_v): 0.574
# Coherence (u_mass): -2.815
# Coherence (c_uci): -0.254
# Coherence (c_npmi): 0.094
# IRBO Topic Diversity: 0.954
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 5} | Time: 12.98s
# Coherence (c_v): 0.566
# Coherence (u_mass): -2.842
# Coherence (c_uci): -0.164
# Coherence (c_npmi): 0.086
# IRBO Topic Diversity: 0.894
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 6} | Time: 11.19s
# Coherence (c_v): 0.33
# Coherence (u_mass): -7.491
# Coherence (c_uci): -4.263
# Coherence (c_npmi): -0.104
# IRBO Topic Diversity: 0.857
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 3} | Time: 12.15s
# Coherence (c_v): 0.339
# Coherence (u_mass): -5.707
# Coherence (c_uci): -2.896
# Coherence (c_npmi): -0.072
# IRBO Topic Diversity: 0.816
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 4} | Time: 12.49s
# Coherence (c_v): 0.325
# Coherence (u_mass): -6.671
# Coherence (c_uci): -3.556
# Coherence (c_npmi): -0.081
# IRBO Topic Diversity: 0.898
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 5} | Time: 12.51s
# Coherence (c_v): 0.333
# Coherence (u_mass): -6.796
# Coherence (c_uci): -3.657
# Coherence (c_npmi): -0.084
# IRBO Topic Diversity: 0.87
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 6} | Time: 13.64s
# Coherence (c_v): 0.577
# Coherence (u_mass): -2.922
# Coherence (c_uci): 0.053
# Coherence (c_npmi): 0.129
# IRBO Topic Diversity: 0.843
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 3} | Time: 12.07s
# Coherence (c_v): 0.604
# Coherence (u_mass): -2.613
# Coherence (c_uci): -1.434
# Coherence (c_npmi): 0.048
# IRBO Topic Diversity: 0.948
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 4} | Time: 12.4s
# Coherence (c_v): 0.594
# Coherence (u_mass): -2.426
# Coherence (c_uci): -1.04
# Coherence (c_npmi): 0.046
# IRBO Topic Diversity: 0.939
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 5} | Time: 11.87s
# Coherence (c_v): 0.611
# Coherence (u_mass): -2.407
# Coherence (c_uci): -0.658
# Coherence (c_npmi): 0.072
# IRBO Topic Diversity: 0.929
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 6} | Time: 12.66s
# Coherence (c_v): 0.33
# Coherence (u_mass): -7.491
# Coherence (c_uci): -4.263
# Coherence (c_npmi): -0.104
# IRBO Topic Diversity: 0.857
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 3} | Time: 12.81s
# Coherence (c_v): 0.47
# Coherence (u_mass): -6.182
# Coherence (c_uci): -4.45
# Coherence (c_npmi): -0.079
# IRBO Topic Diversity: 0.942
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 4} | Time: 12.81s
# Coherence (c_v): 0.44
# Coherence (u_mass): -5.14
# Coherence (c_uci): -3.381
# Coherence (c_npmi): -0.062
# IRBO Topic Diversity: 0.891
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 5} | Time: 13.61s
# Coherence (c_v): 0.426
# Coherence (u_mass): -5.739
# Coherence (c_uci): -4.247
# Coherence (c_npmi): -0.084
# IRBO Topic Diversity: 0.911
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 6} | Time: 11.91s
# Coherence (c_v): 0.537
# Coherence (u_mass): -1.494
# Coherence (c_uci): 0.08
# Coherence (c_npmi): 0.038
# IRBO Topic Diversity: 0.91
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 3} | Time: 13.54s
# Coherence (c_v): 0.536
# Coherence (u_mass): -2.327
# Coherence (c_uci): -0.295
# Coherence (c_npmi): 0.073
# IRBO Topic Diversity: 0.897
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 4} | Time: 14.43s
# Coherence (c_v): 0.577
# Coherence (u_mass): -2.665
# Coherence (c_uci): -0.338
# Coherence (c_npmi): 0.105
# IRBO Topic Diversity: 0.911
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 5} | Time: 13.96s
# Coherence (c_v): 0.626
# Coherence (u_mass): -2.798
# Coherence (c_uci): -0.266
# Coherence (c_npmi): 0.141
# IRBO Topic Diversity: 0.949
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 6} | Time: 13.25s
# Coherence (c_v): 0.335
# Coherence (u_mass): -1.991
# Coherence (c_uci): -0.132
# Coherence (c_npmi): -0.01
# IRBO Topic Diversity: 0.771
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 3} | Time: 12.26s
# Coherence (c_v): 0.373
# Coherence (u_mass): -3.387
# Coherence (c_uci): -1.604
# Coherence (c_npmi): -0.027
# IRBO Topic Diversity: 0.811
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 4} | Time: 12.83s
# Coherence (c_v): 0.356
# Coherence (u_mass): -5.102
# Coherence (c_uci): -2.68
# Coherence (c_npmi): -0.04
# IRBO Topic Diversity: 0.868
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 5} | Time: 13.89s
# Coherence (c_v): 0.432
# Coherence (u_mass): -4.454
# Coherence (c_uci): -2.478
# Coherence (c_npmi): -0.016
# IRBO Topic Diversity: 0.905
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 6} | Time: 15.89s
# Coherence (c_v): 0.577
# Coherence (u_mass): -2.922
# Coherence (c_uci): 0.053
# Coherence (c_npmi): 0.129
# IRBO Topic Diversity: 0.843
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 3} | Time: 12.92s
# Coherence (c_v): 0.564
# Coherence (u_mass): -2.453
# Coherence (c_uci): 0.087
# Coherence (c_npmi): 0.1
# IRBO Topic Diversity: 0.874
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 4} | Time: 15.65s
# Coherence (c_v): 0.574
# Coherence (u_mass): -2.815
# Coherence (c_uci): -0.254
# Coherence (c_npmi): 0.094
# IRBO Topic Diversity: 0.954
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 5} | Time: 13.54s
# Coherence (c_v): 0.566
# Coherence (u_mass): -2.842
# Coherence (c_uci): -0.164
# Coherence (c_npmi): 0.086
# IRBO Topic Diversity: 0.894
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 6} | Time: 14.29s
# Coherence (c_v): 0.33
# Coherence (u_mass): -7.491
# Coherence (c_uci): -4.263
# Coherence (c_npmi): -0.104
# IRBO Topic Diversity: 0.857
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 3} | Time: 15.3s
# Coherence (c_v): 0.339
# Coherence (u_mass): -5.707
# Coherence (c_uci): -2.896
# Coherence (c_npmi): -0.072
# IRBO Topic Diversity: 0.816
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 4} | Time: 13.95s
# Coherence (c_v): 0.325
# Coherence (u_mass): -6.671
# Coherence (c_uci): -3.556
# Coherence (c_npmi): -0.081
# IRBO Topic Diversity: 0.898
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 5} | Time: 13.96s
# Coherence (c_v): 0.333
# Coherence (u_mass): -6.796
# Coherence (c_uci): -3.657
# Coherence (c_npmi): -0.084
# IRBO Topic Diversity: 0.87
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 6} | Time: 14.26s
# Coherence (c_v): 0.553
# Coherence (u_mass): -1.591
# Coherence (c_uci): 0.325
# Coherence (c_npmi): 0.085
# IRBO Topic Diversity: 0.91
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 15, 'min_samples': 5, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 3} | Time: 16.96s
# Coherence (c_v): 0.555
# Coherence (u_mass): -1.495
# Coherence (c_uci): 0.258
# Coherence (c_npmi): 0.068
# IRBO Topic Diversity: 0.947
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 15, 'min_samples': 5, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 4} | Time: 16.49s
# Coherence (c_v): 0.555
# Coherence (u_mass): -1.495
# Coherence (c_uci): 0.258
# Coherence (c_npmi): 0.068
# IRBO Topic Diversity: 0.947
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 15, 'min_samples': 5, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 5} | Time: 28.03s
# Coherence (c_v): 0.555
# Coherence (u_mass): -1.495
# Coherence (c_uci): 0.258
# Coherence (c_npmi): 0.068
# IRBO Topic Diversity: 0.947
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 15, 'min_samples': 5, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 6} | Time: 23.36s
# Coherence (c_v): 0.358
# Coherence (u_mass): -3.752
# Coherence (c_uci): -1.438
# Coherence (c_npmi): -0.018
# IRBO Topic Diversity: 0.843
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 15, 'min_samples': 5, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 3} | Time: 42.14s
# Coherence (c_v): 0.377
# Coherence (u_mass): -3.183
# Coherence (c_uci): -1.102
# Coherence (c_npmi): -0.004
# IRBO Topic Diversity: 0.859
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 15, 'min_samples': 5, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 4} | Time: 26.1s
# Coherence (c_v): 0.377
# Coherence (u_mass): -3.183
# Coherence (c_uci): -1.102
# Coherence (c_npmi): -0.004
# IRBO Topic Diversity: 0.859
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 15, 'min_samples': 5, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 5} | Time: 16.44s
# Coherence (c_v): 0.377
# Coherence (u_mass): -3.183
# Coherence (c_uci): -1.102
# Coherence (c_npmi): -0.004
# IRBO Topic Diversity: 0.859
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 15, 'min_samples': 5, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 6} | Time: 16.88s
# Coherence (c_v): 0.577
# Coherence (u_mass): -2.922
# Coherence (c_uci): 0.053
# Coherence (c_npmi): 0.129
# IRBO Topic Diversity: 0.843
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 5, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 3} | Time: 15.48s
# Coherence (c_v): 0.579
# Coherence (u_mass): -2.362
# Coherence (c_uci): 0.05
# Coherence (c_npmi): 0.098
# IRBO Topic Diversity: 0.908
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 5, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 4} | Time: 14.77s
# Coherence (c_v): 0.605
# Coherence (u_mass): -2.355
# Coherence (c_uci): 0.255
# Coherence (c_npmi): 0.117
# IRBO Topic Diversity: 0.896
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 5, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 5} | Time: 13.22s
# Coherence (c_v): 0.62
# Coherence (u_mass): -2.159
# Coherence (c_uci): 0.354
# Coherence (c_npmi): 0.127
# IRBO Topic Diversity: 0.907
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 5, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 6} | Time: 18.3s
# Coherence (c_v): 0.338
# Coherence (u_mass): -7.23
# Coherence (c_uci): -4.028
# Coherence (c_npmi): -0.095
# IRBO Topic Diversity: 0.857
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 5, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 3} | Time: 15.15s
# Coherence (c_v): 0.344
# Coherence (u_mass): -5.498
# Coherence (c_uci): -2.74
# Coherence (c_npmi): -0.066
# IRBO Topic Diversity: 0.832
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 5, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 4} | Time: 20.68s
# Coherence (c_v): 0.35
# Coherence (u_mass): -5.888
# Coherence (c_uci): -3.416
# Coherence (c_npmi): -0.076
# IRBO Topic Diversity: 0.868
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 5, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 5} | Time: 17.27s
# Coherence (c_v): 0.401
# Coherence (u_mass): -5.225
# Coherence (c_uci): -3.14
# Coherence (c_npmi): -0.059
# IRBO Topic Diversity: 0.877
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 5, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 6} | Time: 18.0s
# Coherence (c_v): 0.414
# Coherence (u_mass): -6.15
# Coherence (c_uci): -2.741
# Coherence (c_npmi): -0.004
# IRBO Topic Diversity: 0.743
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 3} | Time: 22.56s
# Coherence (c_v): 0.556
# Coherence (u_mass): -4.649
# Coherence (c_uci): -1.412
# Coherence (c_npmi): 0.086
# IRBO Topic Diversity: 0.914
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 4} | Time: 20.18s
# Coherence (c_v): 0.573
# Coherence (u_mass): -3.857
# Coherence (c_uci): -1.033
# Coherence (c_npmi): 0.076
# IRBO Topic Diversity: 0.944
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 5} | Time: 16.14s
# Coherence (c_v): 0.601
# Coherence (u_mass): -3.023
# Coherence (c_uci): -0.219
# Coherence (c_npmi): 0.112
# IRBO Topic Diversity: 0.944
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 6} | Time: 17.6s
# Coherence (c_v): 0.324
# Coherence (u_mass): -7.075
# Coherence (c_uci): -4.058
# Coherence (c_npmi): -0.099
# IRBO Topic Diversity: 0.786
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 3} | Time: 16.69s
# Coherence (c_v): 0.382
# Coherence (u_mass): -5.966
# Coherence (c_uci): -3.918
# Coherence (c_npmi): -0.078
# IRBO Topic Diversity: 0.906
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 4} | Time: 13.78s
# Coherence (c_v): 0.419
# Coherence (u_mass): -5.002
# Coherence (c_uci): -2.931
# Coherence (c_npmi): -0.051
# IRBO Topic Diversity: 0.913
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 5} | Time: 15.1s
# Coherence (c_v): 0.409
# Coherence (u_mass): -5.476
# Coherence (c_uci): -3.243
# Coherence (c_npmi): -0.044
# IRBO Topic Diversity: 0.911
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 6} | Time: 20.5s
# Coherence (c_v): 0.666
# Coherence (u_mass): -1.483
# Coherence (c_uci): 0.681
# Coherence (c_npmi): 0.154
# IRBO Topic Diversity: 1.0
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 3} | Time: 21.92s
# Coherence (c_v): 0.651
# Coherence (u_mass): -1.666
# Coherence (c_uci): 0.639
# Coherence (c_npmi): 0.148
# IRBO Topic Diversity: 1.0
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 4} | Time: 20.92s
# Coherence (c_v): 0.604
# Coherence (u_mass): -2.239
# Coherence (c_uci): -0.038
# Coherence (c_npmi): 0.099
# IRBO Topic Diversity: 0.987
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 5} | Time: 19.51s
# Coherence (c_v): 0.644
# Coherence (u_mass): -1.605
# Coherence (c_uci): 0.1
# Coherence (c_npmi): 0.105
# IRBO Topic Diversity: 0.992
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 6} | Time: 16.69s
# Coherence (c_v): 0.384
# Coherence (u_mass): -2.818
# Coherence (c_uci): -1.954
# Coherence (c_npmi): -0.04
# IRBO Topic Diversity: 0.931
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 3} | Time: 19.75s
# Coherence (c_v): 0.393
# Coherence (u_mass): -3.596
# Coherence (c_uci): -2.012
# Coherence (c_npmi): -0.023
# IRBO Topic Diversity: 0.917
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 4} | Time: 27.79s
# Coherence (c_v): 0.395
# Coherence (u_mass): -4.239
# Coherence (c_uci): -2.588
# Coherence (c_npmi): -0.042
# IRBO Topic Diversity: 0.926
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 5} | Time: 20.83s
# Coherence (c_v): 0.433
# Coherence (u_mass): -5.168
# Coherence (c_uci): -3.04
# Coherence (c_npmi): -0.029
# IRBO Topic Diversity: 0.955
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 6} | Time: 22.06s
# Coherence (c_v): 0.433
# Coherence (u_mass): -6.076
# Coherence (c_uci): -2.712
# Coherence (c_npmi): 0.002
# IRBO Topic Diversity: 0.743
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 3} | Time: 24.25s
# Coherence (c_v): 0.462
# Coherence (u_mass): -4.718
# Coherence (c_uci): -1.779
# Coherence (c_npmi): 0.013
# IRBO Topic Diversity: 0.884
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 4} | Time: 20.67s
# Coherence (c_v): 0.494
# Coherence (u_mass): -4.985
# Coherence (c_uci): -2.025
# Coherence (c_npmi): 0.035
# IRBO Topic Diversity: 0.951
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 5} | Time: 16.89s
# Coherence (c_v): 0.534
# Coherence (u_mass): -4.043
# Coherence (c_uci): -1.077
# Coherence (c_npmi): 0.066
# IRBO Topic Diversity: 0.921
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 6} | Time: 17.04s
# Coherence (c_v): 0.324
# Coherence (u_mass): -7.076
# Coherence (c_uci): -4.058
# Coherence (c_npmi): -0.099
# IRBO Topic Diversity: 0.797
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 3} | Time: 12.37s
# Coherence (c_v): 0.326
# Coherence (u_mass): -6.46
# Coherence (c_uci): -3.555
# Coherence (c_npmi): -0.086
# IRBO Topic Diversity: 0.855
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 4} | Time: 11.46s
# Coherence (c_v): 0.345
# Coherence (u_mass): -5.791
# Coherence (c_uci): -3.153
# Coherence (c_npmi): -0.069
# IRBO Topic Diversity: 0.898
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 5} | Time: 12.13s
# Coherence (c_v): 0.35
# Coherence (u_mass): -6.837
# Coherence (c_uci): -3.89
# Coherence (c_npmi): -0.072
# IRBO Topic Diversity: 0.899
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 6} | Time: 13.44s
# Coherence (c_v): 0.414
# Coherence (u_mass): -6.15
# Coherence (c_uci): -2.741
# Coherence (c_npmi): -0.004
# IRBO Topic Diversity: 0.743
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 3} | Time: 13.89s
# Coherence (c_v): 0.556
# Coherence (u_mass): -4.649
# Coherence (c_uci): -1.412
# Coherence (c_npmi): 0.086
# IRBO Topic Diversity: 0.914
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 4} | Time: 12.49s
# Coherence (c_v): 0.573
# Coherence (u_mass): -3.857
# Coherence (c_uci): -1.033
# Coherence (c_npmi): 0.076
# IRBO Topic Diversity: 0.944
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 5} | Time: 12.43s
# Coherence (c_v): 0.601
# Coherence (u_mass): -3.023
# Coherence (c_uci): -0.219
# Coherence (c_npmi): 0.112
# IRBO Topic Diversity: 0.944
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 6} | Time: 14.85s
# Coherence (c_v): 0.324
# Coherence (u_mass): -7.075
# Coherence (c_uci): -4.058
# Coherence (c_npmi): -0.099
# IRBO Topic Diversity: 0.786
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 3} | Time: 12.85s
# Coherence (c_v): 0.382
# Coherence (u_mass): -5.966
# Coherence (c_uci): -3.918
# Coherence (c_npmi): -0.078
# IRBO Topic Diversity: 0.906
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 4} | Time: 13.05s
# Coherence (c_v): 0.419
# Coherence (u_mass): -5.002
# Coherence (c_uci): -2.931
# Coherence (c_npmi): -0.051
# IRBO Topic Diversity: 0.913
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 5} | Time: 11.92s
# Coherence (c_v): 0.409
# Coherence (u_mass): -5.476
# Coherence (c_uci): -3.243
# Coherence (c_npmi): -0.044
# IRBO Topic Diversity: 0.911
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 6} | Time: 12.61s
# Coherence (c_v): 0.533
# Coherence (u_mass): -1.518
# Coherence (c_uci): 0.187
# Coherence (c_npmi): 0.057
# IRBO Topic Diversity: 0.96
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 15, 'min_samples': 5, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 3} | Time: 12.47s
# Coherence (c_v): 0.562
# Coherence (u_mass): -1.622
# Coherence (c_uci): 0.21
# Coherence (c_npmi): 0.062
# IRBO Topic Diversity: 0.973
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 15, 'min_samples': 5, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 4} | Time: 18.56s
# Coherence (c_v): 0.539
# Coherence (u_mass): -2.793
# Coherence (c_uci): -0.834
# Coherence (c_npmi): 0.021
# IRBO Topic Diversity: 0.987
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 15, 'min_samples': 5, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 5} | Time: 19.14s
# Coherence (c_v): 0.597
# Coherence (u_mass): -2.753
# Coherence (c_uci): -0.511
# Coherence (c_npmi): 0.059
# IRBO Topic Diversity: 0.978
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 15, 'min_samples': 5, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 6} | Time: 19.58s
# Coherence (c_v): 0.321
# Coherence (u_mass): -2.222
# Coherence (c_uci): -0.356
# Coherence (c_npmi): -0.017
# IRBO Topic Diversity: 0.836
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 15, 'min_samples': 5, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 3} | Time: 22.42s
# Coherence (c_v): 0.343
# Coherence (u_mass): -3.234
# Coherence (c_uci): -1.318
# Coherence (c_npmi): -0.041
# IRBO Topic Diversity: 0.89
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 15, 'min_samples': 5, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 4} | Time: 19.98s
# Coherence (c_v): 0.345
# Coherence (u_mass): -3.886
# Coherence (c_uci): -1.828
# Coherence (c_npmi): -0.046
# IRBO Topic Diversity: 0.926
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 15, 'min_samples': 5, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 5} | Time: 19.1s
# Coherence (c_v): 0.35
# Coherence (u_mass): -4.573
# Coherence (c_uci): -2.382
# Coherence (c_npmi): -0.044
# IRBO Topic Diversity: 0.931
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 15, 'min_samples': 5, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 6} | Time: 23.74s
# Coherence (c_v): 0.433
# Coherence (u_mass): -6.068
# Coherence (c_uci): -2.712
# Coherence (c_npmi): 0.002
# IRBO Topic Diversity: 0.843
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 5, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 3} | Time: 24.06s
# Coherence (c_v): 0.473
# Coherence (u_mass): -4.514
# Coherence (c_uci): -1.749
# Coherence (c_npmi): 0.019
# IRBO Topic Diversity: 0.908
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 5, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 4} | Time: 22.53s
# Coherence (c_v): 0.472
# Coherence (u_mass): -4.993
# Coherence (c_uci): -2.303
# Coherence (c_npmi): -0.011
# IRBO Topic Diversity: 0.954
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 5, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 5} | Time: 16.9s
# Coherence (c_v): 0.547
# Coherence (u_mass): -3.946
# Coherence (c_uci): -1.231
# Coherence (c_npmi): 0.052
# IRBO Topic Diversity: 0.953
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 5, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 6} | Time: 14.74s
# Coherence (c_v): 0.324
# Coherence (u_mass): -7.075
# Coherence (c_uci): -4.058
# Coherence (c_npmi): -0.099
# IRBO Topic Diversity: 0.836
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 5, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 3} | Time: 16.09s
# Coherence (c_v): 0.378
# Coherence (u_mass): -5.406
# Coherence (c_uci): -2.674
# Coherence (c_npmi): -0.051
# IRBO Topic Diversity: 0.854
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 5, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 4} | Time: 13.62s
# Coherence (c_v): 0.371
# Coherence (u_mass): -5.531
# Coherence (c_uci): -2.845
# Coherence (c_npmi): -0.053
# IRBO Topic Diversity: 0.914
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 5, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 5} | Time: 14.97s
# Coherence (c_v): 0.371
# Coherence (u_mass): -5.894
# Coherence (c_uci): -3.196
# Coherence (c_npmi): -0.05
# IRBO Topic Diversity: 0.918
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 5, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 6} | Time: 13.57s
# Coherence (c_v): 0.577
# Coherence (u_mass): -2.922
# Coherence (c_uci): 0.053
# Coherence (c_npmi): 0.129
# IRBO Topic Diversity: 0.843
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 3} | Time: 14.6s
# Coherence (c_v): 0.561
# Coherence (u_mass): -2.587
# Coherence (c_uci): 0.002
# Coherence (c_npmi): 0.085
# IRBO Topic Diversity: 0.858
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 4} | Time: 14.3s
# Coherence (c_v): 0.591
# Coherence (u_mass): -2.524
# Coherence (c_uci): 0.219
# Coherence (c_npmi): 0.108
# IRBO Topic Diversity: 0.886
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 5} | Time: 16.69s
# Coherence (c_v): 0.575
# Coherence (u_mass): -2.395
# Coherence (c_uci): 0.188
# Coherence (c_npmi): 0.092
# IRBO Topic Diversity: 0.872
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 6} | Time: 14.91s
# Coherence (c_v): 0.28
# Coherence (u_mass): -7.006
# Coherence (c_uci): -3.953
# Coherence (c_npmi): -0.097
# IRBO Topic Diversity: 0.847
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 3} | Time: 18.36s
# Coherence (c_v): 0.311
# Coherence (u_mass): -5.337
# Coherence (c_uci): -2.679
# Coherence (c_npmi): -0.068
# IRBO Topic Diversity: 0.8
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 4} | Time: 19.8s
# Coherence (c_v): 0.349
# Coherence (u_mass): -5.217
# Coherence (c_uci): -2.949
# Coherence (c_npmi): -0.064
# IRBO Topic Diversity: 0.851
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 5} | Time: 22.66s
# Coherence (c_v): 0.386
# Coherence (u_mass): -5.219
# Coherence (c_uci): -2.834
# Coherence (c_npmi): -0.05
# IRBO Topic Diversity: 0.855
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 6} | Time: 26.69s
# Coherence (c_v): 0.577
# Coherence (u_mass): -2.937
# Coherence (c_uci): 0.053
# Coherence (c_npmi): 0.129
# IRBO Topic Diversity: 0.743
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 3} | Time: 24.01s
# Coherence (c_v): 0.592
# Coherence (u_mass): -3.231
# Coherence (c_uci): -1.008
# Coherence (c_npmi): 0.104
# IRBO Topic Diversity: 0.934
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 4} | Time: 24.59s
# Coherence (c_v): 0.576
# Coherence (u_mass): -2.901
# Coherence (c_uci): -0.781
# Coherence (c_npmi): 0.077
# IRBO Topic Diversity: 0.931
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 5} | Time: 24.63s
# Coherence (c_v): 0.627
# Coherence (u_mass): -3.218
# Coherence (c_uci): -0.769
# Coherence (c_npmi): 0.095
# IRBO Topic Diversity: 0.967
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 6} | Time: 22.73s
# Coherence (c_v): 0.302
# Coherence (u_mass): -6.989
# Coherence (c_uci): -3.933
# Coherence (c_npmi): -0.096
# IRBO Topic Diversity: 0.807
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 3} | Time: 22.68s
# Coherence (c_v): 0.298
# Coherence (u_mass): -8.738
# Coherence (c_uci): -5.287
# Coherence (c_npmi): -0.124
# IRBO Topic Diversity: 0.924
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 4} | Time: 14.32s
# Coherence (c_v): 0.316
# Coherence (u_mass): -7.051
# Coherence (c_uci): -4.038
# Coherence (c_npmi): -0.103
# IRBO Topic Diversity: 0.876
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 5} | Time: 13.2s
# Coherence (c_v): 0.334
# Coherence (u_mass): -7.396
# Coherence (c_uci): -4.323
# Coherence (c_npmi): -0.093
# IRBO Topic Diversity: 0.899
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 6} | Time: 11.77s
# Coherence (c_v): 0.577
# Coherence (u_mass): -2.937
# Coherence (c_uci): 0.053
# Coherence (c_npmi): 0.129
# IRBO Topic Diversity: 0.743
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 3} | Time: 12.39s
# Coherence (c_v): 0.594
# Coherence (u_mass): -2.686
# Coherence (c_uci): 0.105
# Coherence (c_npmi): 0.104
# IRBO Topic Diversity: 0.934
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 4} | Time: 11.93s
# Coherence (c_v): 0.584
# Coherence (u_mass): -4.285
# Coherence (c_uci): -1.314
# Coherence (c_npmi): 0.042
# IRBO Topic Diversity: 0.967
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 5} | Time: 11.28s
# Coherence (c_v): 0.566
# Coherence (u_mass): -4.586
# Coherence (c_uci): -1.531
# Coherence (c_npmi): 0.058
# IRBO Topic Diversity: 0.965
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 6} | Time: 11.18s
# Coherence (c_v): 0.289
# Coherence (u_mass): -6.992
# Coherence (c_uci): -3.93
# ...
# Coherence (c_v): 0.296
# Coherence (u_mass): -7.552
# Coherence (c_uci): -3.392
# Coherence (c_npmi): -0.076
# IRBO Topic Diversity: 0.564
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 4} | Time: 10.1s
# Coherence (c_v): 0.296
# Coherence (u_mass): -7.552
# Coherence (c_uci): -3.392
# Coherence (c_npmi): -0.076
# IRBO Topic Diversity: 0.564
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 5} | Time: 10.53s
# Coherence (c_v): 0.296
# Coherence (u_mass): -7.552
# Coherence (c_uci): -3.392
# Coherence (c_npmi): -0.076
# IRBO Topic Diversity: 0.564
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 6} | Time: 10.07s
# Coherence (c_v): 0.522
# Coherence (u_mass): -2.942
# Coherence (c_uci): -0.755
# Coherence (c_npmi): 0.031
# IRBO Topic Diversity: 1.0
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 3} | Time: 9.8s
# Coherence (c_v): 0.528
# Coherence (u_mass): -3.228
# Coherence (c_uci): -1.088
# Coherence (c_npmi): 0.027
# IRBO Topic Diversity: 0.934
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 4} | Time: 9.95s
# Coherence (c_v): 0.612
# Coherence (u_mass): -2.338
# Coherence (c_uci): 0.118
# Coherence (c_npmi): 0.108
# IRBO Topic Diversity: 0.936
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 5} | Time: 10.65s
# Coherence (c_v): 0.609
# Coherence (u_mass): -2.718
# Coherence (c_uci): -1.089
# Coherence (c_npmi): 0.053
# IRBO Topic Diversity: 0.966
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 6} | Time: 10.31s
# Coherence (c_v): 0.294
# Coherence (u_mass): -2.937
# Coherence (c_uci): -1.074
# Coherence (c_npmi): -0.049
# IRBO Topic Diversity: 0.921
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 3} | Time: 10.67s
# Coherence (c_v): 0.327
# Coherence (u_mass): -4.857
# Coherence (c_uci): -2.378
# Coherence (c_npmi): -0.053
# IRBO Topic Diversity: 0.88
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 4} | Time: 10.12s
# Coherence (c_v): 0.354
# Coherence (u_mass): -5.5
# Coherence (c_uci): -2.501
# Coherence (c_npmi): -0.026
# IRBO Topic Diversity: 0.886
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 5} | Time: 11.0s
# Coherence (c_v): 0.348
# Coherence (u_mass): -7.1
# Coherence (c_uci): -3.806
# Coherence (c_npmi): -0.066
# IRBO Topic Diversity: 0.928
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 6} | Time: 10.99s
# Coherence (c_v): 0.5
# Coherence (u_mass): -2.748
# Coherence (c_uci): -0.863
# Coherence (c_npmi): 0.022
# IRBO Topic Diversity: 0.91
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 3} | Time: 11.1s
# Coherence (c_v): 0.518
# Coherence (u_mass): -2.566
# Coherence (c_uci): -0.606
# Coherence (c_npmi): 0.024
# IRBO Topic Diversity: 0.973
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 4} | Time: 9.81s
# Coherence (c_v): 0.524
# Coherence (u_mass): -2.478
# Coherence (c_uci): -0.451
# Coherence (c_npmi): 0.027
# IRBO Topic Diversity: 0.908
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 5} | Time: 10.21s
# Coherence (c_v): 0.56
# Coherence (u_mass): -3.623
# Coherence (c_uci): -1.128
# Coherence (c_npmi): 0.056
# IRBO Topic Diversity: 0.943
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 6} | Time: 10.0s
# Coherence (c_v): 0.332
# Coherence (u_mass): -5.296
# Coherence (c_uci): -2.562
# Coherence (c_npmi): -0.038
# IRBO Topic Diversity: 0.809
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 3} | Time: 10.26s
# Coherence (c_v): 0.349
# Coherence (u_mass): -5.105
# Coherence (c_uci): -2.685
# Coherence (c_npmi): -0.059
# IRBO Topic Diversity: 0.904
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 4} | Time: 10.47s
# Coherence (c_v): 0.359
# Coherence (u_mass): -4.604
# Coherence (c_uci): -2.611
# Coherence (c_npmi): -0.059
# IRBO Topic Diversity: 0.86
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 5} | Time: 10.31s
# Coherence (c_v): 0.377
# Coherence (u_mass): -5.587
# Coherence (c_uci): -3.424
# Coherence (c_npmi): -0.073
# IRBO Topic Diversity: 0.905
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 6} | Time: 10.09s
# Coherence (c_v): 0.531
# Coherence (u_mass): -1.598
# Coherence (c_uci): 0.074
# Coherence (c_npmi): 0.03
# IRBO Topic Diversity: 0.91
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 15, 'min_samples': 5, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 3} | Time: 10.38s
# Coherence (c_v): 0.531
# Coherence (u_mass): -1.598
# Coherence (c_uci): 0.074
# Coherence (c_npmi): 0.03
# IRBO Topic Diversity: 0.91
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 15, 'min_samples': 5, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 4} | Time: 10.4s
# Coherence (c_v): 0.531
# Coherence (u_mass): -1.598
# Coherence (c_uci): 0.074
# Coherence (c_npmi): 0.03
# IRBO Topic Diversity: 0.91
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 15, 'min_samples': 5, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 5} | Time: 10.57s
# Coherence (c_v): 0.531
# Coherence (u_mass): -1.598
# Coherence (c_uci): 0.074
# Coherence (c_npmi): 0.03
# IRBO Topic Diversity: 0.91
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 15, 'min_samples': 5, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 6} | Time: 10.63s
# Coherence (c_v): 0.288
# Coherence (u_mass): -2.74
# Coherence (c_uci): -0.859
# Coherence (c_npmi): -0.044
# IRBO Topic Diversity: 0.795
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 15, 'min_samples': 5, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 3} | Time: 9.93s
# Coherence (c_v): 0.288
# Coherence (u_mass): -2.74
# Coherence (c_uci): -0.859
# Coherence (c_npmi): -0.044
# IRBO Topic Diversity: 0.795
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 15, 'min_samples': 5, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 4} | Time: 10.57s
# Coherence (c_v): 0.288
# Coherence (u_mass): -2.74
# Coherence (c_uci): -0.859
# Coherence (c_npmi): -0.044
# IRBO Topic Diversity: 0.795
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 15, 'min_samples': 5, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 5} | Time: 10.27s
# Coherence (c_v): 0.288
# Coherence (u_mass): -2.74
# Coherence (c_uci): -0.859
# Coherence (c_npmi): -0.044
# IRBO Topic Diversity: 0.795
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 15, 'min_samples': 5, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 6} | Time: 10.29s
# Coherence (c_v): 0.531
# Coherence (u_mass): -1.598
# Coherence (c_uci): 0.074
# Coherence (c_npmi): 0.03
# IRBO Topic Diversity: 0.91
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 5, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 3} | Time: 13.64s
# Coherence (c_v): 0.531
# Coherence (u_mass): -1.598
# Coherence (c_uci): 0.074
# Coherence (c_npmi): 0.03
# IRBO Topic Diversity: 0.91
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 5, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 4} | Time: 13.3s
# Coherence (c_v): 0.531
# Coherence (u_mass): -1.598
# Coherence (c_uci): 0.074
# Coherence (c_npmi): 0.03
# IRBO Topic Diversity: 0.91
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 5, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 5} | Time: 11.71s
# Coherence (c_v): 0.531
# Coherence (u_mass): -1.598
# Coherence (c_uci): 0.074
# Coherence (c_npmi): 0.03
# IRBO Topic Diversity: 0.91
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 5, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 6} | Time: 12.15s
# Coherence (c_v): 0.288
# Coherence (u_mass): -2.74
# Coherence (c_uci): -0.859
# Coherence (c_npmi): -0.044
# IRBO Topic Diversity: 0.795
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 5, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 3} | Time: 11.85s
# Coherence (c_v): 0.288
# Coherence (u_mass): -2.74
# Coherence (c_uci): -0.859
# Coherence (c_npmi): -0.044
# IRBO Topic Diversity: 0.795
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 5, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 4} | Time: 11.02s
# Coherence (c_v): 0.288
# Coherence (u_mass): -2.74
# Coherence (c_uci): -0.859
# Coherence (c_npmi): -0.044
# IRBO Topic Diversity: 0.795
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 5, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 5} | Time: 11.56s
# Coherence (c_v): 0.288
# Coherence (u_mass): -2.74
# Coherence (c_uci): -0.859
# Coherence (c_npmi): -0.044
# IRBO Topic Diversity: 0.795
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 5, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 6} | Time: 11.28s
#
# All models completed in 11120.28 seconds.
# Model saved to src/models/bertopic_top3/positive/best_positive_model_top1, embedding saved to src/models/bertopic_top3/positive/embeddings_top1
# Model saved to src/models/bertopic_top3/positive/best_positive_model_top2, embedding saved to src/models/bertopic_top3/positive/embeddings_top2
# Model saved to src/models/bertopic_top3/positive/best_positive_model_top3, embedding saved to src/models/bertopic_top3/positive/embeddings_top3
# Model saved to src/models/bertopic_top3/positive/best_positive_model_top4, embedding saved to src/models/bertopic_top3/positive/embeddings_top4
# Model saved to src/models/bertopic_top3/positive/best_positive_model_top5, embedding saved to src/models/bertopic_top3/positive/embeddings_top5

# %%
df_pos = pd.DataFrame(positive_results)

df_pos["Topics List"] = df_pos["Topics List"].apply(lambda x: str(x))
save_path = 'results/bertopic_top3/'
os.makedirs(save_path, exist_ok=True)
df_pos.sort_values(by="c_v", ascending=False).to_excel(os.path.join(save_path, 'positive_topic_modeling_results.xlsx'), index=False)
df_pos.sort_values(by="c_v", ascending=False).to_csv(os.path.join(save_path, 'positive_topic_modeling_results.csv'), index=False)

# %% [markdown]
# ### **Negative**

# %%
negative_results = run_topic_modeling("negative")
# Out:
# Coherence (c_v): 0.629
# Coherence (u_mass): -1.69
# Coherence (c_uci): 0.412
# Coherence (c_npmi): 0.132
# IRBO Topic Diversity: 1.0
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 3} | Time: 15.38s
# Coherence (c_v): 0.624
# Coherence (u_mass): -1.92
# Coherence (c_uci): 0.476
# Coherence (c_npmi): 0.132
# IRBO Topic Diversity: 0.914
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 4} | Time: 13.1s
# Coherence (c_v): 0.674
# Coherence (u_mass): -1.802
# Coherence (c_uci): 0.547
# Coherence (c_npmi): 0.154
# IRBO Topic Diversity: 0.922
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 5} | Time: 12.39s
# Coherence (c_v): 0.599
# Coherence (u_mass): -3.626
# Coherence (c_uci): -0.925
# Coherence (c_npmi): 0.099
# IRBO Topic Diversity: 0.941
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 6} | Time: 11.51s
# Coherence (c_v): 0.439
# Coherence (u_mass): -2.079
# Coherence (c_uci): 0.057
# Coherence (c_npmi): 0.039
# IRBO Topic Diversity: 0.945
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 3} | Time: 11.87s
# Coherence (c_v): 0.419
# Coherence (u_mass): -3.789
# Coherence (c_uci): -1.482
# Coherence (c_npmi): 0.025
# IRBO Topic Diversity: 0.917
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 4} | Time: 10.77s
# Coherence (c_v): 0.426
# Coherence (u_mass): -5.307
# Coherence (c_uci): -3.071
# Coherence (c_npmi): -0.047
# IRBO Topic Diversity: 0.908
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 5} | Time: 11.21s
# Coherence (c_v): 0.434
# Coherence (u_mass): -5.823
# Coherence (c_uci): -3.154
# Coherence (c_npmi): -0.035
# IRBO Topic Diversity: 0.921
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 6} | Time: 10.77s
# Coherence (c_v): 0.66
# Coherence (u_mass): -1.709
# Coherence (c_uci): 0.563
# Coherence (c_npmi): 0.138
# IRBO Topic Diversity: 1.0
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 3} | Time: 12.19s
# Coherence (c_v): 0.651
# Coherence (u_mass): -2.377
# Coherence (c_uci): 0.083
# Coherence (c_npmi): 0.127
# IRBO Topic Diversity: 0.957
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 4} | Time: 13.01s
# Coherence (c_v): 0.602
# Coherence (u_mass): -2.696
# Coherence (c_uci): -0.755
# Coherence (c_npmi): 0.073
# IRBO Topic Diversity: 0.957
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 5} | Time: 12.32s
# Coherence (c_v): 0.578
# Coherence (u_mass): -3.417
# Coherence (c_uci): -1.571
# Coherence (c_npmi): 0.04
# IRBO Topic Diversity: 0.94
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 6} | Time: 12.73s
# Coherence (c_v): 0.437
# Coherence (u_mass): -4.401
# Coherence (c_uci): -1.894
# Coherence (c_npmi): 0.003
# IRBO Topic Diversity: 0.94
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 3} | Time: 11.35s
# Coherence (c_v): 0.416
# Coherence (u_mass): -4.53
# Coherence (c_uci): -2.15
# Coherence (c_npmi): 0.001
# IRBO Topic Diversity: 0.932
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 4} | Time: 11.6s
# Coherence (c_v): 0.385
# Coherence (u_mass): -5.678
# Coherence (c_uci): -3.279
# Coherence (c_npmi): -0.032
# IRBO Topic Diversity: 0.918
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 5} | Time: 11.13s
# Coherence (c_v): 0.371
# Coherence (u_mass): -7.158
# Coherence (c_uci): -4.086
# Coherence (c_npmi): -0.059
# IRBO Topic Diversity: 0.902
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 6} | Time: 12.0s
# Coherence (c_v): 0.571
# Coherence (u_mass): -1.748
# Coherence (c_uci): 0.192
# Coherence (c_npmi): 0.068
# IRBO Topic Diversity: 1.0
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 3} | Time: 12.43s
# Coherence (c_v): 0.649
# Coherence (u_mass): -1.729
# Coherence (c_uci): 0.748
# Coherence (c_npmi): 0.157
# IRBO Topic Diversity: 0.94
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 4} | Time: 11.6s
# Coherence (c_v): 0.71
# Coherence (u_mass): -1.711
# Coherence (c_uci): 0.926
# Coherence (c_npmi): 0.198
# IRBO Topic Diversity: 0.97
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 5} | Time: 11.08s
# Coherence (c_v): 0.643
# Coherence (u_mass): -3.508
# Coherence (c_uci): -0.479
# Coherence (c_npmi): 0.16
# IRBO Topic Diversity: 0.982
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 6} | Time: 10.78s
# Coherence (c_v): 0.439
# Coherence (u_mass): -2.096
# Coherence (c_uci): 0.057
# Coherence (c_npmi): 0.039
# IRBO Topic Diversity: 0.933
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 3} | Time: 11.41s
# Coherence (c_v): 0.416
# Coherence (u_mass): -5.161
# Coherence (c_uci): -2.118
# Coherence (c_npmi): 0.011
# IRBO Topic Diversity: 0.909
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 4} | Time: 10.93s
# Coherence (c_v): 0.391
# Coherence (u_mass): -6.379
# Coherence (c_uci): -2.938
# Coherence (c_npmi): -0.014
# IRBO Topic Diversity: 0.931
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 5} | Time: 11.74s
# Coherence (c_v): 0.387
# Coherence (u_mass): -7.203
# Coherence (c_uci): -3.516
# Coherence (c_npmi): -0.021
# IRBO Topic Diversity: 0.946
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 6} | Time: 12.04s
# Coherence (c_v): 0.629
# Coherence (u_mass): -1.69
# Coherence (c_uci): 0.412
# Coherence (c_npmi): 0.132
# IRBO Topic Diversity: 1.0
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 3} | Time: 12.19s
# Coherence (c_v): 0.624
# Coherence (u_mass): -1.92
# Coherence (c_uci): 0.476
# Coherence (c_npmi): 0.132
# IRBO Topic Diversity: 0.914
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 4} | Time: 12.61s
# Coherence (c_v): 0.674
# Coherence (u_mass): -1.802
# Coherence (c_uci): 0.547
# Coherence (c_npmi): 0.154
# IRBO Topic Diversity: 0.922
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 5} | Time: 10.78s
# Coherence (c_v): 0.599
# Coherence (u_mass): -3.626
# Coherence (c_uci): -0.925
# Coherence (c_npmi): 0.099
# IRBO Topic Diversity: 0.941
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 6} | Time: 11.05s
# Coherence (c_v): 0.439
# Coherence (u_mass): -2.079
# Coherence (c_uci): 0.057
# Coherence (c_npmi): 0.039
# IRBO Topic Diversity: 0.945
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 3} | Time: 10.75s
# Coherence (c_v): 0.419
# Coherence (u_mass): -3.789
# Coherence (c_uci): -1.482
# Coherence (c_npmi): 0.025
# IRBO Topic Diversity: 0.917
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 4} | Time: 11.08s
# Coherence (c_v): 0.426
# Coherence (u_mass): -5.307
# Coherence (c_uci): -3.071
# Coherence (c_npmi): -0.047
# IRBO Topic Diversity: 0.908
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 5} | Time: 11.51s
# Coherence (c_v): 0.434
# Coherence (u_mass): -5.823
# Coherence (c_uci): -3.154
# Coherence (c_npmi): -0.035
# IRBO Topic Diversity: 0.921
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 6} | Time: 11.7s
# Coherence (c_v): 0.64
# Coherence (u_mass): -1.601
# Coherence (c_uci): 0.437
# Coherence (c_npmi): 0.155
# IRBO Topic Diversity: 1.0
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 15, 'min_samples': 5, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 3} | Time: 11.82s
# Coherence (c_v): 0.598
# Coherence (u_mass): -2.655
# Coherence (c_uci): -0.936
# Coherence (c_npmi): 0.075
# IRBO Topic Diversity: 0.948
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 15, 'min_samples': 5, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 4} | Time: 11.71s
# Coherence (c_v): 0.587
# Coherence (u_mass): -2.965
# Coherence (c_uci): -1.024
# Coherence (c_npmi): 0.081
# IRBO Topic Diversity: 0.901
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 15, 'min_samples': 5, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 5} | Time: 11.06s
# Coherence (c_v): 0.634
# Coherence (u_mass): -2.691
# Coherence (c_uci): -0.568
# Coherence (c_npmi): 0.111
# IRBO Topic Diversity: 0.951
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 15, 'min_samples': 5, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 6} | Time: 11.6s
# Coherence (c_v): 0.479
# Coherence (u_mass): -2.399
# Coherence (c_uci): -0.47
# Coherence (c_npmi): 0.054
# IRBO Topic Diversity: 1.0
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 15, 'min_samples': 5, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 3} | Time: 12.0s
# Coherence (c_v): 0.424
# Coherence (u_mass): -3.594
# Coherence (c_uci): -1.437
# Coherence (c_npmi): 0.028
# IRBO Topic Diversity: 0.924
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 15, 'min_samples': 5, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 4} | Time: 11.75s
# Coherence (c_v): 0.417
# Coherence (u_mass): -3.932
# Coherence (c_uci): -1.745
# Coherence (c_npmi): 0.018
# IRBO Topic Diversity: 0.877
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 15, 'min_samples': 5, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 5} | Time: 11.69s
# Coherence (c_v): 0.417
# Coherence (u_mass): -4.902
# Coherence (c_uci): -2.27
# Coherence (c_npmi): 0.008
# IRBO Topic Diversity: 0.92
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 15, 'min_samples': 5, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 6} | Time: 18.94s
# Coherence (c_v): 0.581
# Coherence (u_mass): -1.718
# Coherence (c_uci): 0.217
# Coherence (c_npmi): 0.091
# IRBO Topic Diversity: 1.0
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 5, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 3} | Time: 10.53s
# Coherence (c_v): 0.596
# Coherence (u_mass): -2.616
# Coherence (c_uci): -0.993
# Coherence (c_npmi): 0.063
# IRBO Topic Diversity: 0.948
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 5, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 4} | Time: 11.33s
# Coherence (c_v): 0.652
# Coherence (u_mass): -2.384
# Coherence (c_uci): -0.431
# Coherence (c_npmi): 0.105
# IRBO Topic Diversity: 0.974
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 5, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 5} | Time: 12.52s
# Coherence (c_v): 0.585
# Coherence (u_mass): -3.27
# Coherence (c_uci): -1.634
# Coherence (c_npmi): 0.036
# IRBO Topic Diversity: 0.965
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 5, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 6} | Time: 12.19s
# Coherence (c_v): 0.432
# Coherence (u_mass): -2.289
# Coherence (c_uci): -0.381
# Coherence (c_npmi): 0.028
# IRBO Topic Diversity: 0.969
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 5, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 3} | Time: 11.37s
# Coherence (c_v): 0.428
# Coherence (u_mass): -3.414
# Coherence (c_uci): -1.306
# Coherence (c_npmi): 0.03
# IRBO Topic Diversity: 0.926
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 5, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 4} | Time: 11.58s
# Coherence (c_v): 0.394
# Coherence (u_mass): -4.94
# Coherence (c_uci): -2.362
# Coherence (c_npmi): -0.003
# IRBO Topic Diversity: 0.941
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 5, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 5} | Time: 11.99s
# Coherence (c_v): 0.403
# Coherence (u_mass): -6.341
# Coherence (c_uci): -3.562
# Coherence (c_npmi): -0.043
# IRBO Topic Diversity: 0.929
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 7, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 5, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 6} | Time: 12.17s
# Coherence (c_v): 0.631
# Coherence (u_mass): -1.578
# Coherence (c_uci): 0.49
# Coherence (c_npmi): 0.148
# IRBO Topic Diversity: 1.0
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 3} | Time: 11.5s
# Coherence (c_v): 0.606
# Coherence (u_mass): -2.287
# Coherence (c_uci): 0.062
# Coherence (c_npmi): 0.129
# IRBO Topic Diversity: 0.97
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 4} | Time: 11.59s
# Coherence (c_v): 0.534
# Coherence (u_mass): -3.435
# Coherence (c_uci): -1.552
# Coherence (c_npmi): 0.04
# IRBO Topic Diversity: 0.959
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 5} | Time: 11.37s
# Coherence (c_v): 0.582
# Coherence (u_mass): -3.018
# Coherence (c_uci): -1.069
# Coherence (c_npmi): 0.064
# IRBO Topic Diversity: 0.983
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 6} | Time: 12.24s
# Coherence (c_v): 0.442
# Coherence (u_mass): -2.384
# Coherence (c_uci): -0.423
# Coherence (c_npmi): 0.026
# IRBO Topic Diversity: 0.952
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 3} | Time: 11.51s
# Coherence (c_v): 0.407
# Coherence (u_mass): -4.815
# Coherence (c_uci): -2.12
# Coherence (c_npmi): -0.007
# IRBO Topic Diversity: 0.948
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 4} | Time: 10.33s
# Coherence (c_v): 0.395
# Coherence (u_mass): -4.902
# Coherence (c_uci): -2.348
# Coherence (c_npmi): -0.01
# IRBO Topic Diversity: 0.92
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 5} | Time: 11.06s
# Coherence (c_v): 0.381
# Coherence (u_mass): -6.406
# Coherence (c_uci): -3.732
# Coherence (c_npmi): -0.063
# IRBO Topic Diversity: 0.95
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 6} | Time: 11.95s
# Coherence (c_v): 0.631
# Coherence (u_mass): -1.578
# Coherence (c_uci): 0.49
# Coherence (c_npmi): 0.148
# IRBO Topic Diversity: 1.0
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 3} | Time: 11.33s
# Coherence (c_v): 0.629
# Coherence (u_mass): -2.626
# Coherence (c_uci): -0.811
# Coherence (c_npmi): 0.101
# IRBO Topic Diversity: 0.914
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 4} | Time: 12.4s
# Coherence (c_v): 0.581
# Coherence (u_mass): -2.966
# Coherence (c_uci): -1.053
# Coherence (c_npmi): 0.075
# IRBO Topic Diversity: 0.908
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 5} | Time: 10.79s
# Coherence (c_v): 0.595
# Coherence (u_mass): -3.217
# Coherence (c_uci): -1.089
# Coherence (c_npmi): 0.079
# IRBO Topic Diversity: 0.942
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 6} | Time: 10.62s
# Coherence (c_v): 0.442
# Coherence (u_mass): -2.391
# Coherence (c_uci): -0.423
# Coherence (c_npmi): 0.026
# IRBO Topic Diversity: 0.952
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 3} | Time: 10.69s
# Coherence (c_v): 0.434
# Coherence (u_mass): -3.257
# Coherence (c_uci): -1.548
# Coherence (c_npmi): 0.009
# IRBO Topic Diversity: 0.904
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 4} | Time: 11.32s
# Coherence (c_v): 0.442
# Coherence (u_mass): -3.545
# Coherence (c_uci): -1.505
# Coherence (c_npmi): 0.019
# IRBO Topic Diversity: 0.886
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 5} | Time: 11.64s
# Coherence (c_v): 0.418
# Coherence (u_mass): -4.825
# Coherence (c_uci): -2.581
# Coherence (c_npmi): -0.023
# IRBO Topic Diversity: 0.914
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 6} | Time: 12.65s
# Coherence (c_v): 0.558
# Coherence (u_mass): -1.792
# Coherence (c_uci): 0.266
# Coherence (c_npmi): 0.085
# IRBO Topic Diversity: 0.843
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 3} | Time: 10.99s
# Coherence (c_v): 0.601
# Coherence (u_mass): -1.838
# Coherence (c_uci): 0.405
# Coherence (c_npmi): 0.132
# IRBO Topic Diversity: 0.948
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 4} | Time: 11.38s
# Coherence (c_v): 0.601
# Coherence (u_mass): -2.161
# Coherence (c_uci): 0.124
# Coherence (c_npmi): 0.131
# IRBO Topic Diversity: 0.937
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 5} | Time: 11.34s
# Coherence (c_v): 0.627
# Coherence (u_mass): -2.529
# Coherence (c_uci): -0.564
# Coherence (c_npmi): 0.104
# IRBO Topic Diversity: 0.963
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 6} | Time: 11.28s
# Coherence (c_v): 0.418
# Coherence (u_mass): -2.457
# Coherence (c_uci): -0.616
# Coherence (c_npmi): 0.018
# IRBO Topic Diversity: 0.793
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 3} | Time: 11.98s
# Coherence (c_v): 0.383
# Coherence (u_mass): -3.383
# Coherence (c_uci): -1.962
# Coherence (c_npmi): -0.038
# IRBO Topic Diversity: 0.897
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 4} | Time: 10.89s
# Coherence (c_v): 0.363
# Coherence (u_mass): -5.081
# Coherence (c_uci): -2.805
# Coherence (c_npmi): -0.037
# IRBO Topic Diversity: 0.905
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 5} | Time: 10.5s
# Coherence (c_v): 0.37
# Coherence (u_mass): -6.811
# Coherence (c_uci): -4.164
# Coherence (c_npmi): -0.08
# IRBO Topic Diversity: 0.94
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 6} | Time: 10.65s
# Coherence (c_v): 0.631
# Coherence (u_mass): -1.578
# Coherence (c_uci): 0.49
# Coherence (c_npmi): 0.148
# IRBO Topic Diversity: 1.0
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 3} | Time: 10.68s
# Coherence (c_v): 0.606
# Coherence (u_mass): -2.287
# Coherence (c_uci): 0.062
# Coherence (c_npmi): 0.129
# IRBO Topic Diversity: 0.97
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 4} | Time: 12.38s
# Coherence (c_v): 0.534
# Coherence (u_mass): -3.435
# Coherence (c_uci): -1.552
# Coherence (c_npmi): 0.04
# IRBO Topic Diversity: 0.959
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 5} | Time: 11.39s
# Coherence (c_v): 0.582
# Coherence (u_mass): -3.018
# Coherence (c_uci): -1.069
# Coherence (c_npmi): 0.064
# IRBO Topic Diversity: 0.983
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 6} | Time: 11.39s
# Coherence (c_v): 0.442
# Coherence (u_mass): -2.384
# Coherence (c_uci): -0.423
# Coherence (c_npmi): 0.026
# IRBO Topic Diversity: 0.952
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 3} | Time: 11.39s
# Coherence (c_v): 0.407
# Coherence (u_mass): -4.815
# Coherence (c_uci): -2.12
# Coherence (c_npmi): -0.007
# IRBO Topic Diversity: 0.948
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 4} | Time: 11.03s
# Coherence (c_v): 0.395
# Coherence (u_mass): -4.902
# Coherence (c_uci): -2.348
# Coherence (c_npmi): -0.01
# IRBO Topic Diversity: 0.92
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 5} | Time: 10.63s
# Coherence (c_v): 0.381
# Coherence (u_mass): -6.406
# Coherence (c_uci): -3.732
# Coherence (c_npmi): -0.063
# IRBO Topic Diversity: 0.95
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 6} | Time: 12.22s
# Coherence (c_v): 0.645
# Coherence (u_mass): -1.643
# Coherence (c_uci): 0.485
# Coherence (c_npmi): 0.15
# IRBO Topic Diversity: 1.0
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 15, 'min_samples': 5, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 3} | Time: 10.74s
# Coherence (c_v): 0.623
# Coherence (u_mass): -1.8
# Coherence (c_uci): 0.426
# Coherence (c_npmi): 0.136
# IRBO Topic Diversity: 0.948
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 15, 'min_samples': 5, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 4} | Time: 11.1s
# Coherence (c_v): 0.609
# Coherence (u_mass): -2.269
# Coherence (c_uci): -0.014
# Coherence (c_npmi): 0.128
# IRBO Topic Diversity: 0.909
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 15, 'min_samples': 5, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 5} | Time: 11.04s
# Coherence (c_v): 0.632
# Coherence (u_mass): -2.675
# Coherence (c_uci): -0.685
# Coherence (c_npmi): 0.101
# IRBO Topic Diversity: 0.899
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 15, 'min_samples': 5, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 6} | Time: 11.27s
# Coherence (c_v): 0.416
# Coherence (u_mass): -2.637
# Coherence (c_uci): -0.941
# Coherence (c_npmi): 0.004
# IRBO Topic Diversity: 0.979
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 15, 'min_samples': 5, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 3} | Time: 11.62s
# Coherence (c_v): 0.421
# Coherence (u_mass): -3.095
# Coherence (c_uci): -1.093
# Coherence (c_npmi): 0.012
# IRBO Topic Diversity: 0.891
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 15, 'min_samples': 5, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 4} | Time: 11.2s
# Coherence (c_v): 0.403
# Coherence (u_mass): -4.583
# Coherence (c_uci): -2.156
# Coherence (c_npmi): 0.0
# IRBO Topic Diversity: 0.845
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 15, 'min_samples': 5, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 5} | Time: 10.5s
# Coherence (c_v): 0.401
# Coherence (u_mass): -4.351
# Coherence (c_uci): -2.324
# Coherence (c_npmi): -0.002
# IRBO Topic Diversity: 0.866
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 15, 'min_samples': 5, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 6} | Time: 11.19s
# Coherence (c_v): 0.645
# Coherence (u_mass): -1.634
# Coherence (c_uci): 0.485
# Coherence (c_npmi): 0.15
# IRBO Topic Diversity: 1.0
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 5, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 3} | Time: 11.13s
# Coherence (c_v): 0.678
# Coherence (u_mass): -1.642
# Coherence (c_uci): 0.614
# Coherence (c_npmi): 0.152
# IRBO Topic Diversity: 1.0
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 5, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 4} | Time: 11.53s
# Coherence (c_v): 0.653
# Coherence (u_mass): -1.76
# Coherence (c_uci): 0.537
# Coherence (c_npmi): 0.141
# IRBO Topic Diversity: 0.967
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 5, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 5} | Time: 12.45s
# Coherence (c_v): 0.636
# Coherence (u_mass): -2.118
# Coherence (c_uci): 0.163
# Coherence (c_npmi): 0.134
# IRBO Topic Diversity: 0.947
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 5, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 6} | Time: 10.69s
# Coherence (c_v): 0.416
# Coherence (u_mass): -2.653
# Coherence (c_uci): -0.941
# Coherence (c_npmi): 0.004
# IRBO Topic Diversity: 0.935
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 5, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 3} | Time: 11.29s
# Coherence (c_v): 0.38
# Coherence (u_mass): -5.048
# Coherence (c_uci): -2.819
# Coherence (c_npmi): -0.053
# IRBO Topic Diversity: 0.975
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 5, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 4} | Time: 10.49s
# Coherence (c_v): 0.39
# Coherence (u_mass): -5.446
# Coherence (c_uci): -2.865
# Coherence (c_npmi): -0.042
# IRBO Topic Diversity: 0.941
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 5, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 5} | Time: 10.72s
# Coherence (c_v): 0.395
# Coherence (u_mass): -5.318
# Coherence (c_uci): -2.787
# Coherence (c_npmi): -0.028
# IRBO Topic Diversity: 0.916
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.1, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 5, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 6} | Time: 11.67s
# Coherence (c_v): 0.581
# Coherence (u_mass): -1.673
# Coherence (c_uci): 0.217
# Coherence (c_npmi): 0.091
# IRBO Topic Diversity: 1.0
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 3} | Time: 11.0s
# Coherence (c_v): 0.703
# Coherence (u_mass): -1.659
# Coherence (c_uci): 0.594
# Coherence (c_npmi): 0.145
# IRBO Topic Diversity: 1.0
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 4} | Time: 11.37s
# Coherence (c_v): 0.683
# Coherence (u_mass): -2.321
# Coherence (c_uci): 0.107
# Coherence (c_npmi): 0.132
# IRBO Topic Diversity: 0.974
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 5} | Time: 10.41s
# Coherence (c_v): 0.633
# Coherence (u_mass): -2.675
# Coherence (c_uci): -0.27
# Coherence (c_npmi): 0.105
# IRBO Topic Diversity: 0.946
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 6} | Time: 10.4s
# Coherence (c_v): 0.447
# Coherence (u_mass): -2.184
# Coherence (c_uci): -0.658
# Coherence (c_npmi): 0.019
# IRBO Topic Diversity: 0.952
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 3} | Time: 11.49s
# Coherence (c_v): 0.468
# Coherence (u_mass): -3.72
# Coherence (c_uci): -1.333
# Coherence (c_npmi): 0.027
# IRBO Topic Diversity: 0.94
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 4} | Time: 11.08s
# Coherence (c_v): 0.436
# Coherence (u_mass): -4.264
# Coherence (c_uci): -1.96
# Coherence (c_npmi): 0.012
# IRBO Topic Diversity: 0.945
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 5} | Time: 10.42s
# Coherence (c_v): 0.452
# Coherence (u_mass): -4.319
# Coherence (c_uci): -1.789
# Coherence (c_npmi): 0.026
# IRBO Topic Diversity: 0.919
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 6} | Time: 11.1s
# Coherence (c_v): 0.581
# Coherence (u_mass): -1.673
# Coherence (c_uci): 0.217
# Coherence (c_npmi): 0.091
# IRBO Topic Diversity: 1.0
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 3} | Time: 10.86s
# Coherence (c_v): 0.595
# Coherence (u_mass): -2.575
# Coherence (c_uci): -0.307
# Coherence (c_npmi): 0.092
# IRBO Topic Diversity: 0.914
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 4} | Time: 12.92s
# Coherence (c_v): 0.683
# Coherence (u_mass): -2.321
# Coherence (c_uci): 0.107
# Coherence (c_npmi): 0.132
# IRBO Topic Diversity: 0.974
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 5} | Time: 13.21s
# Coherence (c_v): 0.619
# Coherence (u_mass): -3.248
# Coherence (c_uci): -1.135
# Coherence (c_npmi): 0.07
# IRBO Topic Diversity: 0.943
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 6} | Time: 10.66s
# Coherence (c_v): 0.447
# Coherence (u_mass): -2.184
# Coherence (c_uci): -0.658
# Coherence (c_npmi): 0.019
# IRBO Topic Diversity: 0.952
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 3} | Time: 10.69s
# Coherence (c_v): 0.416
# Coherence (u_mass): -3.095
# Coherence (c_uci): -1.411
# Coherence (c_npmi): 0.011
# IRBO Topic Diversity: 0.909
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 4} | Time: 10.98s
# Coherence (c_v): 0.436
# Coherence (u_mass): -4.272
# Coherence (c_uci): -1.96
# Coherence (c_npmi): 0.012
# IRBO Topic Diversity: 0.944
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 5} | Time: 10.65s
# Coherence (c_v): 0.406
# Coherence (u_mass): -4.859
# Coherence (c_uci): -2.275
# Coherence (c_npmi): -0.001
# IRBO Topic Diversity: 0.914
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 6} | Time: 11.1s
# Coherence (c_v): 0.527
# Coherence (u_mass): -1.669
# Coherence (c_uci): 0.233
# Coherence (c_npmi): 0.08
# IRBO Topic Diversity: 0.843
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 3} | Time: 11.18s
# Coherence (c_v): 0.601
# Coherence (u_mass): -1.857
# Coherence (c_uci): 0.405
# Coherence (c_npmi): 0.132
# IRBO Topic Diversity: 0.948
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 4} | Time: 10.41s
# Coherence (c_v): 0.549
# Coherence (u_mass): -3.966
# Coherence (c_uci): -1.256
# Coherence (c_npmi): 0.093
# IRBO Topic Diversity: 0.974
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 5} | Time: 10.8s
# Coherence (c_v): 0.54
# Coherence (u_mass): -5.264
# Coherence (c_uci): -3.045
# Coherence (c_npmi): -0.001
# IRBO Topic Diversity: 0.98
# [✓] Finished model - Embedding: LazarusNLP/all-indo-e5-small-v4, UMAP: {'n_neighbors': 5, 'min_dist': 0.0, 'metric': 'cosine'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 6} | Time: 10.7s
# Coherence (c_v): 0.398
# Coherence (u_mass): -2.922
# Coherence (c_uci): -0.519
# Coherence (c_npmi): 0.036
# IRBO Topic Diversity: 0.809
# ...
# Coherence (c_v): 0.417
# Coherence (u_mass): -5.136
# Coherence (c_uci): -1.899
# Coherence (c_npmi): 0.036
# IRBO Topic Diversity: 0.768
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 4} | Time: 18.34s
# Coherence (c_v): 0.417
# Coherence (u_mass): -5.136
# Coherence (c_uci): -1.899
# Coherence (c_npmi): 0.036
# IRBO Topic Diversity: 0.768
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 5} | Time: 18.22s
# Coherence (c_v): 0.417
# Coherence (u_mass): -5.136
# Coherence (c_uci): -1.899
# Coherence (c_npmi): 0.036
# IRBO Topic Diversity: 0.768
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 6} | Time: 18.5s
# Coherence (c_v): 0.56
# Coherence (u_mass): -1.788
# Coherence (c_uci): 0.565
# Coherence (c_npmi): 0.107
# IRBO Topic Diversity: 0.843
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 3} | Time: 18.53s
# Coherence (c_v): 0.641
# Coherence (u_mass): -1.403
# Coherence (c_uci): 0.74
# Coherence (c_npmi): 0.172
# IRBO Topic Diversity: 0.794
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 4} | Time: 18.15s
# Coherence (c_v): 0.641
# Coherence (u_mass): -1.403
# Coherence (c_uci): 0.74
# Coherence (c_npmi): 0.172
# IRBO Topic Diversity: 0.794
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 5} | Time: 18.56s
# Coherence (c_v): 0.641
# Coherence (u_mass): -1.403
# Coherence (c_uci): 0.74
# Coherence (c_npmi): 0.172
# IRBO Topic Diversity: 0.794
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 6} | Time: 19.21s
# Coherence (c_v): 0.342
# Coherence (u_mass): -6.671
# Coherence (c_uci): -2.649
# Coherence (c_npmi): -0.024
# IRBO Topic Diversity: 0.823
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 3} | Time: 18.14s
# Coherence (c_v): 0.417
# Coherence (u_mass): -5.136
# Coherence (c_uci): -1.899
# Coherence (c_npmi): 0.036
# IRBO Topic Diversity: 0.768
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 4} | Time: 18.63s
# Coherence (c_v): 0.417
# Coherence (u_mass): -5.136
# Coherence (c_uci): -1.899
# Coherence (c_npmi): 0.036
# IRBO Topic Diversity: 0.768
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 5} | Time: 18.85s
# Coherence (c_v): 0.417
# Coherence (u_mass): -5.136
# Coherence (c_uci): -1.899
# Coherence (c_npmi): 0.036
# IRBO Topic Diversity: 0.768
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 6} | Time: 18.49s
# Coherence (c_v): 0.553
# Coherence (u_mass): -1.211
# Coherence (c_uci): 0.202
# Coherence (c_npmi): 0.088
# IRBO Topic Diversity: 0.78
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 3} | Time: 17.98s
# Coherence (c_v): 0.553
# Coherence (u_mass): -1.211
# Coherence (c_uci): 0.202
# Coherence (c_npmi): 0.088
# IRBO Topic Diversity: 0.78
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 4} | Time: 18.18s
# Coherence (c_v): 0.553
# Coherence (u_mass): -1.211
# Coherence (c_uci): 0.202
# Coherence (c_npmi): 0.088
# IRBO Topic Diversity: 0.78
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 5} | Time: 18.94s
# Coherence (c_v): 0.553
# Coherence (u_mass): -1.211
# Coherence (c_uci): 0.202
# Coherence (c_npmi): 0.088
# IRBO Topic Diversity: 0.78
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 6} | Time: 20.02s
# Coherence (c_v): 0.362
# Coherence (u_mass): -2.959
# Coherence (c_uci): -0.999
# Coherence (c_npmi): 0.01
# IRBO Topic Diversity: 0.686
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 3} | Time: 18.94s
# Coherence (c_v): 0.362
# Coherence (u_mass): -2.959
# Coherence (c_uci): -0.999
# Coherence (c_npmi): 0.01
# IRBO Topic Diversity: 0.686
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 4} | Time: 19.96s
# Coherence (c_v): 0.362
# Coherence (u_mass): -2.959
# Coherence (c_uci): -0.999
# Coherence (c_npmi): 0.01
# IRBO Topic Diversity: 0.686
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 5} | Time: 18.06s
# Coherence (c_v): 0.362
# Coherence (u_mass): -2.959
# Coherence (c_uci): -0.999
# Coherence (c_npmi): 0.01
# IRBO Topic Diversity: 0.686
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 3, 'cluster_selection_epsilon': 0.3}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 6} | Time: 17.62s
# Coherence (c_v): 0.553
# Coherence (u_mass): -1.211
# Coherence (c_uci): 0.202
# Coherence (c_npmi): 0.088
# IRBO Topic Diversity: 0.78
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 15, 'min_samples': 5, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 3} | Time: 18.17s
# Coherence (c_v): 0.553
# Coherence (u_mass): -1.211
# Coherence (c_uci): 0.202
# Coherence (c_npmi): 0.088
# IRBO Topic Diversity: 0.78
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 15, 'min_samples': 5, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 4} | Time: 33.27s
# Coherence (c_v): 0.553
# Coherence (u_mass): -1.211
# Coherence (c_uci): 0.202
# Coherence (c_npmi): 0.088
# IRBO Topic Diversity: 0.78
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 15, 'min_samples': 5, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 5} | Time: 18.13s
# Coherence (c_v): 0.553
# Coherence (u_mass): -1.211
# Coherence (c_uci): 0.202
# Coherence (c_npmi): 0.088
# IRBO Topic Diversity: 0.78
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 15, 'min_samples': 5, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 6} | Time: 2214.17s
# Coherence (c_v): 0.395
# Coherence (u_mass): -2.759
# Coherence (c_uci): -0.399
# Coherence (c_npmi): 0.048
# IRBO Topic Diversity: 0.675
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 15, 'min_samples': 5, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 3} | Time: 28.38s
# Coherence (c_v): 0.395
# Coherence (u_mass): -2.759
# Coherence (c_uci): -0.399
# Coherence (c_npmi): 0.048
# IRBO Topic Diversity: 0.675
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 15, 'min_samples': 5, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 4} | Time: 26.51s
# Coherence (c_v): 0.395
# Coherence (u_mass): -2.759
# Coherence (c_uci): -0.399
# Coherence (c_npmi): 0.048
# IRBO Topic Diversity: 0.675
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 15, 'min_samples': 5, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 5} | Time: 26.64s
# Coherence (c_v): 0.395
# Coherence (u_mass): -2.759
# Coherence (c_uci): -0.399
# Coherence (c_npmi): 0.048
# IRBO Topic Diversity: 0.675
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 15, 'min_samples': 5, 'cluster_selection_epsilon': 0.0}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 6} | Time: 21.59s
# Coherence (c_v): 0.553
# Coherence (u_mass): -1.211
# Coherence (c_uci): 0.202
# Coherence (c_npmi): 0.088
# IRBO Topic Diversity: 0.78
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 5, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 3} | Time: 23.91s
# Coherence (c_v): 0.553
# Coherence (u_mass): -1.211
# Coherence (c_uci): 0.202
# Coherence (c_npmi): 0.088
# IRBO Topic Diversity: 0.78
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 5, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 4} | Time: 18.39s
# Coherence (c_v): 0.553
# Coherence (u_mass): -1.211
# Coherence (c_uci): 0.202
# Coherence (c_npmi): 0.088
# IRBO Topic Diversity: 0.78
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 5, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 5} | Time: 17.14s
# Coherence (c_v): 0.553
# Coherence (u_mass): -1.211
# Coherence (c_uci): 0.202
# Coherence (c_npmi): 0.088
# IRBO Topic Diversity: 0.78
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 5, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 5, 'nr_topics': 6} | Time: 17.13s
# Coherence (c_v): 0.395
# Coherence (u_mass): -2.759
# Coherence (c_uci): -0.399
# Coherence (c_npmi): 0.048
# IRBO Topic Diversity: 0.675
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 5, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 3} | Time: 23.16s
# Coherence (c_v): 0.395
# Coherence (u_mass): -2.759
# Coherence (c_uci): -0.399
# Coherence (c_npmi): 0.048
# IRBO Topic Diversity: 0.675
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 5, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 4} | Time: 22.55s
# Coherence (c_v): 0.395
# Coherence (u_mass): -2.759
# Coherence (c_uci): -0.399
# Coherence (c_npmi): 0.048
# IRBO Topic Diversity: 0.675
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 5, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 5} | Time: 16.95s
# Coherence (c_v): 0.395
# Coherence (u_mass): -2.759
# Coherence (c_uci): -0.399
# Coherence (c_npmi): 0.048
# IRBO Topic Diversity: 0.675
# [✓] Finished model - Embedding: sentence-transformers/multi-qa-MiniLM-L6-cos-v1, UMAP: {'n_neighbors': 15, 'min_dist': 0.3, 'metric': 'euclidean'}, HDBSCAN: {'min_cluster_size': 10, 'min_samples': 5, 'cluster_selection_epsilon': 0.5}, BERTopic Params: {'top_n_words': 10, 'nr_topics': 6} | Time: 19.37s
#
# All models completed in 13306.57 seconds.
# Model saved to src/models/bertopic_top3/negative/best_negative_model_top1, embedding saved to src/models/bertopic_top3/negative/embeddings_top1
# Model saved to src/models/bertopic_top3/negative/best_negative_model_top2, embedding saved to src/models/bertopic_top3/negative/embeddings_top2
# Model saved to src/models/bertopic_top3/negative/best_negative_model_top3, embedding saved to src/models/bertopic_top3/negative/embeddings_top3
# Model saved to src/models/bertopic_top3/negative/best_negative_model_top4, embedding saved to src/models/bertopic_top3/negative/embeddings_top4
# Model saved to src/models/bertopic_top3/negative/best_negative_model_top5, embedding saved to src/models/bertopic_top3/negative/embeddings_top5

# %%
df_neg = pd.DataFrame(negative_results)
df_neg["Topics List"] = df_neg["Topics List"].apply(lambda x: str(x))

save_path = 'results/bertopic_top3/'
os.makedirs(save_path, exist_ok=True)
df_neg.sort_values(by="c_v", ascending=False).to_excel(os.path.join(save_path, 'negative_topic_modeling_results.xlsx'), index=False)
df_neg.sort_values(by="c_v", ascending=False).to_csv(os.path.join(save_path, 'negative_topic_modeling_results.csv'), index=False)

# %% [markdown]
# ## **Summary**

# %% [markdown]
# The top-3 models from each sentiment will later be evaluated by human judgement where it will be the final decision to pick the final model for each sentiment.
